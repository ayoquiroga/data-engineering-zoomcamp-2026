# %%
import pyspark

# %%
pyspark.__file__
# Out:
# '/workspaces/data-engineering-zoomcamp-2026/.venv/lib/python3.12/site-packages/pyspark/__init__.py'

# %%
from pyspark.sql import SparkSession

# %%
import os
import sys

# Configurar Java 21 en lugar de Java 25
os.environ['JAVA_HOME'] = '/usr/lib/jvm/java-21-openjdk-amd64'
os.environ['PATH'] = f"{os.environ['JAVA_HOME']}/bin:{os.environ['PATH']}"

print(f"JAVA_HOME: {os.environ['JAVA_HOME']}")
# Out:
# JAVA_HOME: /usr/lib/jvm/java-21-openjdk-amd64

# %%
spark = SparkSession.builder \
    .master("local[*]") \
    .appName('test') \
    .config("spark.sql.warehouse.dir", "/tmp/spark-warehouse") \
    .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/03/06 02:33:09 WARN Utils: Your hostname, codespaces-29ba17, resolves to a loopback address: 127.0.0.1; using 10.0.11.113 instead (on interface eth0)
# 26/03/06 02:33:09 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/06 02:33:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# !wget https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Out:
# --2026-03-06 02:33:29--  https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.114.112, 52.216.57.192, 52.216.41.128, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.114.112|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2026-03-06 02:33:29 ERROR 403: Forbidden.

# %%
# !head taxi+_zone_lookup.csv
# Out:
# "LocationID","Borough","Zone","service_zone"
# 1,"EWR","Newark Airport","EWR"
# 2,"Queens","Jamaica Bay","Boro Zone"
# 3,"Bronx","Allerton/Pelham Gardens","Boro Zone"
# 4,"Manhattan","Alphabet City","Yellow Zone"
# 5,"Staten Island","Arden Heights","Boro Zone"
# 6,"Staten Island","Arrochar/Fort Wadsworth","Boro Zone"
# 7,"Queens","Astoria","Boro Zone"
# 8,"Queens","Astoria Park","Boro Zone"
# 9,"Queens","Auburndale","Boro Zone"

# %%
df = spark.read \
    .option("header", "true") \
    .csv('taxi+_zone_lookup.csv')

# %%
df.show()
# Out:
# +----------+-------------+--------------------+------------+
# |LocationID|      Borough|                Zone|service_zone|
# +----------+-------------+--------------------+------------+
# |         1|          EWR|      Newark Airport|         EWR|
# |         2|       Queens|         Jamaica Bay|   Boro Zone|
# |         3|        Bronx|Allerton/Pelham G...|   Boro Zone|
# |         4|    Manhattan|       Alphabet City| Yellow Zone|
# |         5|Staten Island|       Arden Heights|   Boro Zone|
# |         6|Staten Island|Arrochar/Fort Wad...|   Boro Zone|
# |         7|       Queens|             Astoria|   Boro Zone|
# |         8|       Queens|        Astoria Park|   Boro Zone|
# |         9|       Queens|          Auburndale|   Boro Zone|
# |        10|       Queens|        Baisley Park|   Boro Zone|
# |        11|     Brooklyn|          Bath Beach|   Boro Zone|
# |        12|    Manhattan|        Battery Park| Yellow Zone|
# |        13|    Manhattan|   Battery Park City| Yellow Zone|
# |        14|     Brooklyn|           Bay Ridge|   Boro Zone|
# |        15|       Queens|Bay Terrace/Fort ...|   Boro Zone|
# |        16|       Queens|             Bayside|   Boro Zone|
# |        17|     Brooklyn|             Bedford|   Boro Zone|
# |        18|        Bronx|        Bedford Park|   Boro Zone|
# |        19|       Queens|           Bellerose|   Boro Zone|
# |        20|        Bronx|             Belmont|   Boro Zone|
# +----------+-------------+--------------------+------------+
# only showing top 20 rows

# %%
df.write.parquet('zones')

# %%
# !ls -lh
# Out:
# total 160K
# -rw-rw-rw-  1 codespace codespace 7.7K Mar  6 02:12 03_test.ipynb
# -rw-rw-rw-  1 codespace codespace  19K Mar  6 02:12 04_pyspark.ipynb
# -rw-rw-rw-  1 codespace codespace  33K Mar  6 02:12 05_taxi_schema.ipynb
# -rw-rw-rw-  1 codespace codespace 8.7K Mar  6 02:12 06_spark_sql.ipynb
# -rw-rw-rw-  1 codespace codespace 2.5K Mar  6 02:12 06_spark_sql.py
# -rw-rw-rw-  1 codespace codespace 2.6K Mar  6 02:12 06_spark_sql_big_query.py
# -rw-rw-rw-  1 codespace codespace 7.6K Mar  6 02:12 07_groupby_join.ipynb
# -rw-rw-rw-  1 codespace codespace  12K Mar  6 02:12 08_rdds.ipynb
# -rw-rw-rw-  1 codespace codespace 4.3K Mar  6 02:12 09_spark_gcs.ipynb
# -rw-rw-rw-  1 codespace codespace 3.8K Mar  6 02:12 cloud.md
# -rw-rw-rw-  1 codespace codespace  544 Mar  6 02:12 download_data.sh
# -rw-rw-rw-  1 codespace codespace  17K Mar  6 02:12 homework.ipynb
# -rw-rw-rw-  1 codespace codespace  13K Mar  6 02:23 taxi+_zone_lookup.csv
# drwxr-xr-x+ 2 codespace codespace 4.0K Mar  6 02:33 zones
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 33304)
# Traceback (most recent call last):
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 318, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 349, in process_request
#     self.finish_request(request, client_address)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 362, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 761, in __init__
#     self.handle()
#   File "/workspaces/data-engineering-zoomcamp-2026/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 300, in handle
#     poll(authenticate_and_accum_updates)
#   File "/workspaces/data-engineering-zoomcamp-2026/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 272, in poll
#     if self.rfile in r and func():
#                            ^^^^^^
#   File "/workspaces/data-engineering-zoomcamp-2026/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 293, in authenticate_and_accum_updates
#     raise ValueError(
# ValueError: The value of the provided token to the AccumulatorServer is not correct.
# ----------------------------------------
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 33310)
# Traceback (most recent call last):
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 318, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 349, in process_request
#     self.finish_request(request, client_address)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 362, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 761, in __init__
#     self.handle()
#   File "/workspaces/data-engineering-zoomcamp-2026/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 300, in handle
#     poll(authenticate_and_accum_updates)
#   File "/workspaces/data-engineering-zoomcamp-2026/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 272, in poll
#     if self.rfile in r and func():
#                            ^^^^^^
#   File "/workspaces/data-engineering-zoomcamp-2026/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 293, in authenticate_and_accum_updates
#     raise ValueError(
# ValueError: The value of the provided token to the AccumulatorServer is not correct.
# ----------------------------------------
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 33320)
# Traceback (most recent call last):
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 318, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 349, in process_request
#     self.finish_request(request, client_address)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 362, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 761, in __init__
#     self.handle()
#   File "/workspaces/data-engineering-zoomcamp-2026/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 300, in handle
#     poll(authenticate_and_accum_updates)
#   File "/workspaces/data-engineering-zoomcamp-2026/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 272, in poll
#     if self.rfile in r and func():
#                            ^^^^^^
#   File "/workspaces/data-engineering-zoomcamp-2026/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 293, in authenticate_and_accum_updates
#     raise ValueError(
# ValueError: The value of the provided token to the AccumulatorServer is not correct.
# ----------------------------------------
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 33334)
# Traceback (most recent call last):
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 318, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 349, in process_request
#     self.finish_request(request, client_address)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 362, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 761, in __init__
#     self.handle()
#   File "/workspaces/data-engineering-zoomcamp-2026/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 300, in handle
#     poll(authenticate_and_accum_updates)
#   File "/workspaces/data-engineering-zoomcamp-2026/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 272, in poll
#     if self.rfile in r and func():
#                            ^^^^^^
#   File "/workspaces/data-engineering-zoomcamp-2026/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 293, in authenticate_and_accum_updates
#     raise ValueError(
# ValueError: The value of the provided token to the AccumulatorServer is not correct.
# ----------------------------------------
